# %%
import pyspark

# %%
from pyspark.sql import SparkSession

# %%
session = SparkSession.builder.appName("Default Session").getOrCreate()
session
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://DESKTOP-QNHTSI5.mshome.net:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.4.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Default Session</code></dd>
#             </dl>
#         </div>
#
#             </div>
